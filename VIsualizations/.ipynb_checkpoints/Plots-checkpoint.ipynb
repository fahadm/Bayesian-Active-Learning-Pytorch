# %%
import numpy as np

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
data = {}
funs = ["BALD","MEAN_STD","RANDOM","VAR_RATIOS","MAX_ENTROPY"]
train = {}
val = {}
test = {}
train_accuracy= {}
train_loss= {}
test_accuracy = {}
test_loss = {}
val_accuracy = {}
val_loss = {}
for x in ["test","train","val"]:
    data[x] = {}
    for y in ["acc","loss"]:
        if x == "train" and y == "acc":
            continue 
        data[x][y] = {}
        for z in funs:
            data[x][y][z] = np.load("./"+x+"_"+y+"_"+z+".npy")

# %%
colors = ["r","b","g","m","y"]
x = np.array(range(2,100))


for idx,z in enumerate(funs):
    plt.plot(x,np.array(data["val"]["acc"][z]),colors[idx])
plt.ylabel('Validation Accuracy')

plt.xlabel ('Acquisition iterations ')

plt.ylim(80,100)

plt.show()


colors = ["r","b","g","m","y"]
x = np.array(range(2,100))


for idx,z in enumerate(funs):
    plt.plot(x,np.array(data["test"]["acc"][z]),colors[idx])
plt.ylabel('Test Accuracy')

plt.xlabel ('Acquisition iterations ')
plt.ylim(80,100)

plt.show()
